# %% [markdown]
# <a href="https://colab.research.google.com/github/hy0won/-/blob/master/Wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LIBRARY

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %% [markdown]
# DATA ANALYSIS & CLEANING

# %%
# Load Data
train = pd.read_csv("../content/train.csv")
test = pd.read_csv("../content/test.csv")
sample_submission = pd.read_csv("../content/sample_submission.csv")

# %%
# drop
train = train.drop(['index'], axis=1)
train.head(5)
# Out:
#    quality  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        5            5.6             0.695         0.06             6.8
# 1        5            8.8             0.610         0.14             2.4
# 2        5            7.9             0.210         0.39             2.0
# 3        6            7.0             0.210         0.31             6.0
# 4        6            7.8             0.400         0.26             9.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.042                  9.0                  84.0  0.99432  3.44
# 1      0.067                 10.0                  42.0  0.99690  3.19
# 2      0.057                 21.0                 138.0  0.99176  3.05
# 3      0.046                 29.0                 108.0  0.99390  3.26
# 4      0.059                 32.0                 178.0  0.99550  3.04
#
#    sulphates  alcohol   type
# 0       0.44     10.2  white
# 1       0.59      9.5    red
# 2       0.52     10.9  white
# 3       0.50     10.8  white
# 4       0.43     10.9  white

# %%
train.shape, test.shape
# Out:
# ((5497, 13), (1000, 13))

# %%
# info 활용
train.info()
train.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5497 entries, 0 to 5496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   quality               5497 non-null   int64
#  1   fixed acidity         5497 non-null   float64
#  2   volatile acidity      5497 non-null   float64
#  3   citric acid           5497 non-null   float64
#  4   residual sugar        5497 non-null   float64
#  5   chlorides             5497 non-null   float64
#  6   free sulfur dioxide   5497 non-null   float64
#  7   total sulfur dioxide  5497 non-null   float64
#  8   density               5497 non-null   float64
#  9   pH                    5497 non-null   float64
#  10  sulphates             5497 non-null   float64
#  11  alcohol               5497 non-null   float64
#  12  type                  5497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 558.4+ KB
#             quality  fixed acidity  volatile acidity  citric acid  \
# count   5497.000000    5497.000000       5497.000000  5497.000000
# unique          NaN            NaN               NaN          NaN
# top             NaN            NaN               NaN          NaN
# freq            NaN            NaN               NaN          NaN
# mean       5.818992       7.210115          0.338163     0.318543
# std        0.870311       1.287579          0.163224     0.145104
# min        3.000000       3.800000          0.080000     0.000000
# 25%        5.000000       6.400000          0.230000     0.250000
# 50%        6.000000       7.000000          0.290000     0.310000
# 75%        6.000000       7.700000          0.400000     0.390000
# max        9.000000      15.900000          1.580000     1.660000
#
#         residual sugar    chlorides  free sulfur dioxide  \
# count      5497.000000  5497.000000          5497.000000
# unique             NaN          NaN                  NaN
# top                NaN          NaN                  NaN
# freq               NaN          NaN                  NaN
# mean          5.438075     0.055808            30.417682
# std           4.756676     0.034653            17.673881
# min           0.600000     0.009000             1.000000
# 25%           1.800000     0.038000            17.000000
# 50%           3.000000     0.047000            29.000000
# 75%           8.100000     0.064000            41.000000
# max          65.800000     0.610000           289.000000
#
#         total sulfur dioxide      density           pH    sulphates  \
# count            5497.000000  5497.000000  5497.000000  5497.000000
# unique                   NaN          NaN          NaN          NaN
# top                      NaN          NaN          NaN          NaN
# freq                     NaN          NaN          NaN          NaN
# mean              115.566491     0.994673     3.219502     0.530524
# std                56.288223     0.003014     0.160713     0.149396
# min                 6.000000     0.987110     2.740000     0.220000
# 25%                78.000000     0.992300     3.110000     0.430000
# 50%               118.000000     0.994800     3.210000     0.510000
# 75%               155.000000     0.996930     3.320000     0.600000
# max               440.000000     1.038980     4.010000     2.000000
#
#             alcohol   type
# count   5497.000000   5497
# unique          NaN      2
# top             NaN  white
# freq            NaN   4159
# mean      10.504918    NaN
# std        1.194524    NaN
# min        8.000000    NaN
# 25%        9.500000    NaN
# 50%       10.300000    NaN
# 75%       11.300000    NaN
# max       14.900000    NaN

# %% [markdown]
# EDA & VIZ

# %%
print(train['quality'].value_counts())
sns.countplot(x=train['quality']);
plt.title("dist. of type", fontfamily='serif',fontsize=12);
# Out:
# 6    2416
# 5    1788
# 7     924
# 4     186
# 8     152
# 3      26
# 9       5
# Name: quality, dtype: int64

# %%
#distribution by 'quality'
numerical_columns = train.select_dtypes(exclude='object').columns.tolist()
numerical_columns.remove('quality')

def show_dist_plot(df, columns):
  for column in columns:
    f, ax = plt.subplots(1,2,figsize=(16,4))
    sns.stripplot(x=df['quality'],y=df[column], ax=ax[0],hue=df['quality'])
    sns.violinplot(data=df, x='quality', y=column, ax=ax[1])

show_dist_plot(train, numerical_columns)

# %%
# 피쳐들의 수가 50개면 너무 많아서 분석하기 힘들어서
# train.corr() 상관관계를 통해서 힌트를 얻는다

plt.figure(figsize=(18,8))
corr = train.corr()
sns.heatmap(corr, annot = True, square=False, vmin=-.6, vmax=1.0)

#  분포에서 관계가 있다는 것만 알려주는 거지 원인과 결과의 관계는 아니다

# %% [markdown]
# MODELING

# %%
#Library
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.metrics import plot_roc_curve,accuracy_score, confusion_matrix, plot_confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# %%
#Standardscaler
# numerical_columns 숫자형 데이터가 있는 컬럼만 가져오기
ss = StandardScaler() #표준화 작업

train[numerical_columns] = ss.fit_transform(train[numerical_columns])

#factorize
train['type'] = pd.factorize(train['type'])[0]
train.head()
# Out:
#    quality  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        5      -1.250611          2.186377    -1.781940        0.286345
# 1        5       1.234899          1.665574    -1.230560       -0.638755
# 2        5       0.535849         -0.785265     0.492500       -0.722855
# 3        6      -0.163201         -0.785265    -0.058879        0.118145
# 4        6       0.458177          0.378883    -0.403491        0.854020
#
#    chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0  -0.398500            -1.211937             -0.560852 -0.117252  1.372128
# 1   0.322998            -1.155351             -1.307080  0.738864 -0.183584
# 2   0.034399            -0.532907              0.398583 -0.966732 -1.054782
# 3  -0.283060            -0.080221             -0.134436 -0.256620  0.252016
# 4   0.092119             0.089537              1.109276  0.274305 -1.117010
#
#    sulphates   alcohol  type
# 0  -0.605988 -0.255287     0
# 1   0.398147 -0.841348     1
# 2  -0.070450  0.330774     0
# 3  -0.204334  0.247051     0
# 4  -0.672931  0.330774     0

# %%
X = train.drop(['quality'], axis=1)
y = train.quality

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=42)
# test_size : 0.2 train과 test를 8:2로 구분한다는 의미
#random_state : 42 같은 값으로 나오게 하기 위한 Seed 설정

# %%
X_train.shape, X_test.shape
# Out:
# ((5455, 12), (42, 12))

# %%
def Model(model):
    model.fit(X_train,y_train)
    score = model.score(X_test,y_test)
    model_train_score= model.score(X_train,y_train)
    model_test_score=model.score(X_test,y_test)
    prediction = model.predict(X_test)
    cm = confusion_matrix(y_test, prediction)
    print("Testing Score\n", score)
    plot_confusion_matrix(model,X_test,y_test,cmap='OrRd')

# %%
#RandomForest
rf= RandomForestClassifier()
rf.fit(X_train,y_train)
Model(rf)
# Out:
# Testing Score
#  0.6904761904761905
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
#feature의 수가 동일한지 보고, train set에서 다룬 것처럼 testset에서 다루어 줍니다.
X_train.shape, test.shape
# Out:
# ((5455, 12), (1000, 13))

# %%
#drop index column
test= test.drop(['index'],axis=1)

#Standardscaler
ss= StandardScaler()
test[numerical_columns] = ss.fit_transform(test[numerical_columns])

#factorize
test['type'] = pd.factorize(test['type'])[0]

test.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       1.306951         -0.220579     1.098184        0.236865  -0.385503
# 1       4.507070          0.477272     1.780836       -0.749722   0.343645
# 2      -0.553583         -0.395042    -0.335387       -0.057012  -0.466520
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -1.108531             -0.756734 -0.352060 -1.943080  -1.068114
# 1            -0.888114             -1.327873  1.915724 -0.949812  -0.311854
# 2             0.709907              1.077835 -0.008456 -0.142782   1.063164
#
#     alcohol  type
# 0  1.000172     0
# 1 -1.203025     1
# 2 -0.864071     0

# %%
final_pred = rf.predict(test)

# %%
#submission
sample_submission['quality'] = final_pred
sample_submission.to_csv("../content/sample_submission.csv",index=False)

# %%
#분류에 있어 각 피쳐에 대한 중요도 출력
rf.fit(X_train, y_train)
print(rf.feature_importances_)
# Out:
# [0.0753688  0.09905635 0.07978093 0.08503481 0.08553876 0.08471952
#  0.09061428 0.10073103 0.08304111 0.08675405 0.12600523 0.00335513]
